# %%
import pandas as pd

# %%
df = pd.read_csv("..\data\global_power_plant_database.csv")

# %%
df.head()
# Out:
#   country country_long                                               name  \
# 0     AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2     AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3     AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4     AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  GEODB0040538        33.00   32.3220    65.1190        Hydro         NaN
# 1  GEODB0040541        66.00   34.5560    69.4787        Hydro         NaN
# 2  GEODB0040534       100.00   34.6410    69.7170        Hydro         NaN
# 3  GEODB0040536        11.55   34.4847    70.3633        Hydro         NaN
# 4  GEODB0040540        42.00   34.5638    69.1134          Gas         NaN
#
#   other_fuel2  ...                                 url  geolocation_source  \
# 0         NaN  ...  http://globalenergyobservatory.org               GEODB
# 1         NaN  ...  http://globalenergyobservatory.org               GEODB
# 2         NaN  ...  http://globalenergyobservatory.org               GEODB
# 3         NaN  ...  http://globalenergyobservatory.org               GEODB
# 4         NaN  ...  http://globalenergyobservatory.org               GEODB
#
#    wepp_id year_of_capacity_data generation_gwh_2013 generation_gwh_2014  \
# 0  1009793                2017.0                 NaN                 NaN
# 1  1009795                2017.0                 NaN                 NaN
# 2  1009797                2017.0                 NaN                 NaN
# 3  1009787                2017.0                 NaN                 NaN
# 4      NaN                2017.0                 NaN                 NaN
#
#   generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 24 columns]

# %%
df_all = df.drop(['country_long', 'name', 'url', 'geolocation_source', 'wepp_id'], axis=1)

# %% [markdown]
# If column `gppd_idnr` is unique, we can set it as index:

# %%
df_all['gppd_idnr'].is_unique
# Out:
# True

# %%
df_all.set_index('gppd_idnr')
# Out:
#              country  capacity_mw  latitude  longitude primary_fuel  \
# gppd_idnr
# GEODB0040538     AFG        33.00   32.3220    65.1190        Hydro
# GEODB0040541     AFG        66.00   34.5560    69.4787        Hydro
# GEODB0040534     AFG       100.00   34.6410    69.7170        Hydro
# GEODB0040536     AFG        11.55   34.4847    70.3633        Hydro
# GEODB0040540     AFG        42.00   34.5638    69.1134          Gas
# ...              ...          ...       ...        ...          ...
# WRI1022386       ZMB        50.00  -12.9667    28.6333          Oil
# WRI1022384       ZMB        20.00  -12.8167    28.2000          Oil
# WRI1022380       ZMB       108.00  -17.9167    25.8500        Hydro
# GEODB0040404     ZWE       920.00  -18.3835    26.4700         Coal
# GEODB0003803     ZWE       750.00  -16.5222    28.7619        Hydro
#
#              other_fuel1 other_fuel2 other_fuel3  commissioning_year  owner  \
# gppd_idnr
# GEODB0040538         NaN         NaN         NaN                 NaN    NaN
# GEODB0040541         NaN         NaN         NaN                 NaN    NaN
# GEODB0040534         NaN         NaN         NaN                 NaN    NaN
# GEODB0040536         NaN         NaN         NaN                 NaN    NaN
# GEODB0040540         NaN         NaN         NaN                 NaN    NaN
# ...                  ...         ...         ...                 ...    ...
# WRI1022386           NaN         NaN         NaN                 NaN  ZESCO
# WRI1022384           NaN         NaN         NaN                 NaN  ZESCO
# WRI1022380           NaN         NaN         NaN                 NaN  ZESCO
# GEODB0040404         NaN         NaN         NaN                 NaN    NaN
# GEODB0003803         NaN         NaN         NaN                 NaN    NaN
#
#                                          source  year_of_capacity_data  \
# gppd_idnr
# GEODB0040538                              GEODB                 2017.0
# GEODB0040541                              GEODB                 2017.0
# GEODB0040534                              GEODB                 2017.0
# GEODB0040536                              GEODB                 2017.0
# GEODB0040540                              GEODB                 2017.0
# ...                                         ...                    ...
# WRI1022386    Energy Regulation Board of Zambia                    NaN
# WRI1022384    Energy Regulation Board of Zambia                    NaN
# WRI1022380    Energy Regulation Board of Zambia                    NaN
# GEODB0040404                              GEODB                 2017.0
# GEODB0003803                              GEODB                 2017.0
#
#               generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# gppd_idnr
# GEODB0040538                  NaN                  NaN                  NaN
# GEODB0040541                  NaN                  NaN                  NaN
# GEODB0040534                  NaN                  NaN                  NaN
# GEODB0040536                  NaN                  NaN                  NaN
# GEODB0040540                  NaN                  NaN                  NaN
# ...                           ...                  ...                  ...
# WRI1022386                    NaN                  NaN                  NaN
# WRI1022384                    NaN                  NaN                  NaN
# WRI1022380                    NaN                  NaN                  NaN
# GEODB0040404                  NaN                  NaN                  NaN
# GEODB0003803                  NaN                  NaN                  NaN
#
#               generation_gwh_2016  generation_gwh_2017  \
# gppd_idnr
# GEODB0040538                  NaN                  NaN
# GEODB0040541                  NaN                  NaN
# GEODB0040534                  NaN                  NaN
# GEODB0040536                  NaN                  NaN
# GEODB0040540                  NaN                  NaN
# ...                           ...                  ...
# WRI1022386                    NaN                  NaN
# WRI1022384                    NaN                  NaN
# WRI1022380                    NaN                  NaN
# GEODB0040404                  NaN                  NaN
# GEODB0003803                  NaN                  NaN
#
#               estimated_generation_gwh
# gppd_idnr
# GEODB0040538                       NaN
# GEODB0040541                       NaN
# GEODB0040534                       NaN
# GEODB0040536                       NaN
# GEODB0040540                       NaN
# ...                                ...
# WRI1022386                  120.872642
# WRI1022384                   48.349057
# WRI1022380                  702.100000
# GEODB0040404               4397.000000
# GEODB0003803               5431.000000
#
# [29910 rows x 18 columns]

# %%
#Split into one dataset containing estimated and one containing time series data
df_time_series = (df_all.dropna(how='all', subset=['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017'])
                      .set_index('gppd_idnr'))


df_time_series_complete = df_time_series.dropna(how='any', subset=['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017'])

df_time_series_incomplete = df_time_series[df_time_series[['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017']].isnull().any(axis=1)]

df_estimate = (df_all.dropna(how='any', subset=['estimated_generation_gwh'])
                   .set_index('gppd_idnr'))

# %%
#We must have some duplicates
len(df_time_series_incomplete)+len(df_estimate)+len(df_time_series_complete)
# Out:
# 31814

# %%
#Some rows have both estimate and incomplete time series:
s1 = pd.merge(df_time_series_incomplete, df_estimate, how='inner')
s1
# Out:
#      country  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0        AUS         50.0  -34.5034   139.0246          Oil         NaN
# 1        AUS         37.0  -23.5525   145.3142          Gas         NaN
# 2        AUS        113.0  -36.5817   149.1083         Wind         NaN
# 3        AUS         53.0  -31.9867   141.3915        Solar         NaN
# 4        AUS        190.0  -20.5447   147.8049         Coal         NaN
# ...      ...          ...       ...        ...          ...         ...
# 2525     VNM         66.0   14.3656   108.6943        Hydro         NaN
# 2526     VNM         28.0   14.3611   108.7203        Hydro         NaN
# 2527     VNM          6.6   21.3412   104.3498        Hydro         NaN
# 2528     VNM         19.5   12.1526   108.3787        Hydro         NaN
# 2529     VNM         30.0   15.8600   107.6538        Hydro         NaN
#
#      other_fuel2 other_fuel3  commissioning_year  \
# 0            NaN         NaN                 NaN
# 1            NaN         NaN                 NaN
# 2            NaN         NaN                 NaN
# 3            NaN         NaN                 NaN
# 4            NaN         NaN                 NaN
# ...          ...         ...                 ...
# 2525         NaN         NaN              2001.0
# 2526         NaN         NaN              2014.0
# 2527         NaN         NaN                 NaN
# 2528         NaN         NaN              2010.0
# 2529         NaN         NaN              2009.0
#
#                                       owner  \
# 0         Infratil Energy Australia Pty Ltd
# 1                  Ergon Energy Qld Pty Ltd
# 2               Boco Rock Wind Farm Pty Ltd
# 3                                AGL Energy
# 4                           RATCH Australia
# ...                                     ...
# 2525     Vinh Son- Song Hinh Hydropower JSC
# 2526     Vinh Son Hydropower Investment JSC
# 2527               Xim Vang Hydro Power JSC
# 2528  Cao Nguyen - Song Da Hydro Power JSC.
# 2529                          Za Hungt JSC.
#
#                                                  source  \
# 0     Australian Renewable Energy Mapping Infrastruc...
# 1     Australian Renewable Energy Mapping Infrastruc...
# 2     Australian Renewable Energy Mapping Infrastruc...
# 3     Australian Renewable Energy Mapping Infrastruc...
# 4     Australian Renewable Energy Mapping Infrastruc...
# ...                                                 ...
# 2525                           Open Development Vietnam
# 2526                           Open Development Vietnam
# 2527                           Open Development Vietnam
# 2528                           Open Development Vietnam
# 2529                           Open Development Vietnam
#
#       year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                       NaN                  NaN                  NaN
# 1                       NaN                  NaN                  NaN
# 2                       NaN                  NaN                  NaN
# 3                       NaN                  NaN                  NaN
# 4                       NaN             0.214722                  NaN
# ...                     ...                  ...                  ...
# 2525                    NaN                  NaN                  NaN
# 2526                    NaN                  NaN                  NaN
# 2527                    NaN                  NaN                  NaN
# 2528                    NaN                  NaN                  NaN
# 2529                    NaN                  NaN                  NaN
#
#       generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                1.653056             5.300833             7.649722
# 1                     NaN                  NaN             3.941667
# 2              208.778611           334.114167           349.301667
# 3                     NaN            92.104722           127.564722
# 4                     NaN                  NaN                  NaN
# ...                   ...                  ...                  ...
# 2525                  NaN           228.500000                  NaN
# 2526                  NaN           103.000000                  NaN
# 2527                  NaN            68.000000                  NaN
# 2528                  NaN            79.000000                  NaN
# 2529                  NaN           122.700000                  NaN
#
#       estimated_generation_gwh
# 0                   526.452790
# 1                    93.304739
# 2                    94.893070
# 3                  1059.946475
# 4                   771.660922
# ...                        ...
# 2525                230.679596
# 2526                 97.864071
# 2527                 23.067960
# 2528                 68.155335
# 2529                104.854362
#
# [2530 rows x 18 columns]

# %%
# Output
#  df_ts_complete: df with values where time series is complete
#  df_estimate: df where all time series values are NaN but there is an estimate
#  df_ts_incomplete: df with values where at least one of time series values is NaN
# 
# Reads global powerplant data data from CSV, drops irrelevant columns, splits df (see output), 
# and re-indexes df with gppdf_idnr as index
def read_clean_and_split():  
    df = pd.read_csv("..\data\global_power_plant_database.csv")
    df_all = df.drop(['country_long', 'name', 'url', 'geolocation_source', 'wepp_id'], axis=1)
    
    df_ts = (df_all.dropna(how='all', subset=['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017'])
                      .set_index('gppd_idnr'))
    df_ts_complete = df_ts.dropna(how='any', subset=['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017'])
    df_estimate = (df_all.dropna(how='any', subset=['estimated_generation_gwh'])
                   .set_index('gppd_idnr'))
    df_ts_incomplete = df_ts[df_ts[['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017']].isnull().any(axis=1)]
    return df_ts_complete, df_ts_incomplete, df_estimate

# %%
# Creates new column 'avg_annual_output' in df by
#  - copying estimated_generation_gwh in rows where it is not NaN
#  - averaging the time series in the remaining rows
def fill_estimate(df):
    df['avg_annual_output'] = df['estimated_generation_gwh']    
    idx = df.index[df['estimated_generation_gwh'].isna()].tolist()    
    df.loc[idx,'avg_annual_output'] = df[['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017']].mean(axis=1)
