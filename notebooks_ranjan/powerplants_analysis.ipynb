# %%
# !pip install geopandas
# !pip install plotly
import plotly
import plotly.express as px
import geopandas as gpd
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: geopandas in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (0.9.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.2.3)
# Requirement already satisfied: shapely>=1.6 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.7.1)
# Requirement already satisfied: pyproj>=2.2.0 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (3.0.1)
# Requirement already satisfied: fiona>=1.8 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from geopandas) (1.8.18)
# Requirement already satisfied: attrs>=17 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: click<8,>=4.0 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (0.7.1)
# Requirement already satisfied: click-plugins>=1.0 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: munch in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from pandas>=0.24.0->geopandas) (1.20.1)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\geo_env\lib\site-packages (from plotly) (1.15.0)

# %%
df = pd.read_csv("global_power_plant_database.csv")
df
# Out:
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 2         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 3         AFG  Afghanistan  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 4         AFG  Afghanistan            Northwest Kabul Power Plant Afghanistan
# ...       ...          ...                                                ...
# 29905     ZMB       Zambia                                              Ndola
# 29906     ZMB       Zambia                                              Nkana
# 29907     ZMB       Zambia                                     Victoria Falls
# 29908     ZWE     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 29909     ZWE     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
#           gppd_idnr  capacity_mw  latitude  longitude primary_fuel  \
# 0      GEODB0040538        33.00   32.3220    65.1190        Hydro
# 1      GEODB0040541        66.00   34.5560    69.4787        Hydro
# 2      GEODB0040534       100.00   34.6410    69.7170        Hydro
# 3      GEODB0040536        11.55   34.4847    70.3633        Hydro
# 4      GEODB0040540        42.00   34.5638    69.1134          Gas
# ...             ...          ...       ...        ...          ...
# 29905    WRI1022386        50.00  -12.9667    28.6333          Oil
# 29906    WRI1022384        20.00  -12.8167    28.2000          Oil
# 29907    WRI1022380       108.00  -17.9167    25.8500        Hydro
# 29908  GEODB0040404       920.00  -18.3835    26.4700         Coal
# 29909  GEODB0003803       750.00  -16.5222    28.7619        Hydro
#
#       other_fuel1 other_fuel2  ...  \
# 0             NaN         NaN  ...
# 1             NaN         NaN  ...
# 2             NaN         NaN  ...
# 3             NaN         NaN  ...
# 4             NaN         NaN  ...
# ...           ...         ...  ...
# 29905         NaN         NaN  ...
# 29906         NaN         NaN  ...
# 29907         NaN         NaN  ...
# 29908         NaN         NaN  ...
# 29909         NaN         NaN  ...
#
#                                                      url  geolocation_source  \
# 0                     http://globalenergyobservatory.org               GEODB
# 1                     http://globalenergyobservatory.org               GEODB
# 2                     http://globalenergyobservatory.org               GEODB
# 3                     http://globalenergyobservatory.org               GEODB
# 4                     http://globalenergyobservatory.org               GEODB
# ...                                                  ...                 ...
# 29905  http://www.erb.org.zm/reports/EnergySectorRepo...        Power Africa
# 29906  http://www.erb.org.zm/reports/EnergySectorRepo...        Power Africa
# 29907  http://www.erb.org.zm/reports/EnergySectorRepo...        Power Africa
# 29908                 http://globalenergyobservatory.org               GEODB
# 29909                 http://globalenergyobservatory.org               GEODB
#
#        wepp_id year_of_capacity_data generation_gwh_2013 generation_gwh_2014  \
# 0      1009793                2017.0                 NaN                 NaN
# 1      1009795                2017.0                 NaN                 NaN
# 2      1009797                2017.0                 NaN                 NaN
# 3      1009787                2017.0                 NaN                 NaN
# 4          NaN                2017.0                 NaN                 NaN
# ...        ...                   ...                 ...                 ...
# 29905  1089529                   NaN                 NaN                 NaN
# 29906  1043097                   NaN                 NaN                 NaN
# 29907  1033763                   NaN                 NaN                 NaN
# 29908  1033856                2017.0                 NaN                 NaN
# 29909  1033857                2017.0                 NaN                 NaN
#
#       generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                     NaN                  NaN                  NaN
# 1                     NaN                  NaN                  NaN
# 2                     NaN                  NaN                  NaN
# 3                     NaN                  NaN                  NaN
# 4                     NaN                  NaN                  NaN
# ...                   ...                  ...                  ...
# 29905                 NaN                  NaN                  NaN
# 29906                 NaN                  NaN                  NaN
# 29907                 NaN                  NaN                  NaN
# 29908                 NaN                  NaN                  NaN
# 29909                 NaN                  NaN                  NaN
#
#        estimated_generation_gwh
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 29905                120.872642
# 29906                 48.349057
# 29907                702.100000
# 29908               4397.000000
# 29909               5431.000000
#
# [29910 rows x 24 columns]

# %%
# plots each of the powerplants based on their latitudes and longitudes and their primary fuel type
fig = px.scatter_geo(df,
                    lat=df["latitude"],
                    lon=df["longitude"],
                    hover_name=df["name"],
                    color = df["primary_fuel"])
fig.show()
# Out:
# <div>                            <div id="6ed9f065-2425-4be0-89f7-e5656cb434e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ed9f065-2425-4be0-89f7-e5656cb434e8")) {                    Plotly.newPlot(                        "6ed9f065-2425-4be0-89f7-e5656cb434e8",                        [{"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>primary_fuel=Hydro<br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>", "hovertext": ["Kajaki Hydroelectric Power Plant Afghanistan", "Mahipar Hydroelectric Power Plant Afghanistan", "Naghlu Dam Hydroelectric Power Plant Afghanistan", "Nangarhar (Darunta) Hydroelectric Power Plant Afghanistan", "Pul-e-Khumri Hydroelectric Power Plant Afghanistan", "Sarobi Dam Hydroelectric Power Plant Afghanistan", "Bistrica 1", "Fierza", "Koman", "Lanabregas", "Shkopet", "Ulez", "Vau i Dijes", "Ighil Emda", "Biopio (hydro)", "Cambambe", "Capanda", "Matala", "Rio Luachimo", "AGUA DEL TORO", "ALICURA", "ALVAREZ CONDARCO", "ARROYITO", "BENJAMIN REOLIN", "CABRA CORRAL", "CACHEUTA (NUEVA)", "CASA DE PIEDRA", "CASSAFFOUSTH", "CH LOS CARACOLES", "CIPOLLETTI", "CUESTA DEL VIENTO", "EL CADILLAL", "EL CARRIZAL", "EL CHOCON", "EL TIGRE", "EL TUNAL", "ESCABA", "FITZ SIMON", "FLORENTINO AMEGHINO", "FUTALEUFU", "GENERAL SAN MARTIN", "GUILLERMO CESPEDES", "H. PICHI PICUN LEUFU", "JULIAN  ROMERO", "LA VI\u00d1A", "LAS MADERAS", "LOS CORONELES (EX 25  DE MAYO)", "LOS MOLINOS I", "LOS MOLINOS II", "LOS QUIROGA", "LOS REYUNOS", "NIHUIL I", "NIHUIL II", "NIHUIL III", "NIHUIL IV", "PIEDRA DEL AGUILA (CPSA)", "PIEDRAS MORAS", "PLANICIE BANDERITA", "PUEBLO VIEJO", "QUEBRADA DE ULLUM", "RIO CORRALITO", "RIO GRANDE", "RIO HONDO", "SALTO ANDERSEN", "SALTO GRANDE (MITAD ARGENTINA)", "SAN ROQUE", "ULLUM", "URUGUA-I", "YACYRETA", "Sevan-Hrazdan Cascade", "Shamb", "Spandaryan", "Tatev", "Banimboola", "Barron Gorge", "Bastyan", "Bendeela (Shoalhaven Scheme)", "Blowering", "Bogong (Mount Beauty Hydro Scheme)", "Brown Mountain", "Burrendong", "Burrinjuck Power Station", "Butlers Gorge", "Catagunya", "Cethana", "Clover", "Cluny", "Copeton", "Dartmouth (Mount Beauty Hydro Scheme)", "Devils Gate", "Eildon", "Eildon Small Hydro", "Fisher", "Glenbawn", "Gordon", "Guthega", "Hume", "Jindabyne Dam Mini Hydro", "John Butters", "Jounama", "Kangaroo Valley (Shoalhaven Scheme)", "Kareeya", "Koombooloomba", "Lake Echo", "Lake Glenmaggie", "Lake Keepit", "Lake William Hovell", "Lemonthyme", "Liapootah", "Lower Lake Margaret", "Lower Rubicon", "Mackintosh", "McKay Creek (Mount Beauty Hydro Scheme)", "Meadowbank", "Murray 1", "Murray 2", "Nieterana", "Nymboida", "Oaky", "Ord River", "Paloona", "Pindari", "Poatina", "Reece", "Repulse", "Rowallan", "Rubicon", "Tarraleah", "Terminal Storage", "The Drop", "Tods Corner", "Trevallyn", "Tribute", "Tumut 1 (Upper Tumut)", "Tumut 2 (Upper Tumut)", "Tumut 3", "Tungatinah", "Upper Lake Margaret", "Warragamba", "Wayatinah", "West Kiewa (Mount Beauty Hydro Scheme)", "Wilmot", "Wivenhoe", "Wivenhoe Hydroelectric", "Wyangala A", "Yarrawonga", "Abwinden-Asten", "Altenmarkt", "Arnstein", "Aschach", "Bischofshofen", "Braunau-Simbach", "Dionysen", "Ering-Frauenstein", "Erzbach", "Feistritz-Ludmannsdorf", "Feldkirchen", "Ferlach Maria Rain", "Fisching", "Freudenau Danube", "Friesach", "Funsingau", "Gabersdorf", "Gaming", "Gerlos", "Gratkorn", "Greifenstein", "Hieflau", "Hieflau-Erzbach", "Jochenstein", "KW Amlach", "KW Imst", "KW Jenbach", "KW Kaunertal", "KW K\u00fchtai", "KW Silz", "Kaprun Limberg II", "Kaprun Oberstufe", "Kaprun main stage", "Kellerberg", "Klammsee", "Klaus", "Kopswerk II", "Kreuzbergmaut", "Kreuzeck days storage", "Krippau", "Landl", "Laufnitzdorf", "Lebring", "Leoben", "Losenstein", "Low Tuxbach - Small power plant Stillupp", "L\u00fcnerseewerk", "Malta S ...
